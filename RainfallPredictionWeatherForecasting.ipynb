# %% [markdown]
# #  Rainfall Prediction Weather Forecasting

# %% [markdown]
# ## Problem Statement:

# %% [markdown]
# Rain Prediction –Weather forecasting
#
# Weather forecasting is the application of science and technology to predict the conditions of the atmosphere for a given location and time. Weather forecasts are made by collecting quantitative data about the current state of the atmosphere at a given place and using meteorology to project how the atmosphere will change. Rain Dataset is to predict whether or not it will rain tomorrow. The Dataset contains about 10 years of daily weather observations of different locations in Australia. Here, predict two things:
#
#     Problem Statement:
#
# a) Design a predictive model with the use of machine learning algorithms to forecast whether or not it will rain tomorrow.
#
# b) Design a predictive model with the use of machine learning algorithms to predict how much rainfall could be there.
#
# Dataset Description:
#
# Number of columns: 23
#
# Date - The date of observation
#
# Location -The common name of the location of the weather station
#
# MinTemp -The minimum temperature in degrees celsius
#
# MaxTemp -The maximum temperature in degrees celsius
#
# Rainfall -The amount of rainfall recorded for the day in mm
#
# Evaporation -The so-called Class A pan evaporation (mm) in the 24 hours to 9am
#
# Sunshine -The number of hours of bright sunshine in the day.
#
# WindGustDi r- The direction of the strongest wind gust in the 24 hours to midnight
#
# WindGustSpeed -The speed (km/h) of the strongest wind gust in the 24 hours to midnight
#
# WindDir9am -Direction of the wind at 9am
#
# WindDir3pm -Direction of the wind at 3pm
#
# WindSpeed9am -Wind speed (km/hr) averaged over 10 minutes prior to 9am
#
# WindSpeed3pm -Wind speed (km/hr) averaged over 10 minutes prior to 3pm
#
# Humidity9am -Humidity (percent) at 9am
#
# Humidity3pm -Humidity (percent) at 3pm
#
# Pressure9am -Atmospheric pressure (hpa) reduced to mean sea level at 9am
#
# Pressure3pm -Atmospheric pressure (hpa) reduced to mean sea level at 3pm
#
# Cloud9am - Fraction of sky obscured by cloud at 9am.
#
# Cloud3pm -Fraction of sky obscured by cloud
#
# Temp9am-Temperature (degrees C) at 9am
#
# Temp3pm -Temperature (degrees C) at 3pm
#
# RainToday -Boolean: 1 if precipitation (mm) in the 24 hours to 9am exceeds 1mm, otherwise 0
#
# RainTomorrow -The amount of next day rain in mm. Used to create response variable . A kind of measure of the "risk".

# %% [markdown]
# #### Importing required packages.

# %%
#Importing required packages.

import os
import pandas as pd
import numpy as np

#ploting libraries
import matplotlib.pyplot as plt
import seaborn as sns


#feature engineering
from scipy.stats import zscore
from sklearn.preprocessing import StandardScaler, LabelEncoder

#train test split and #cross validation
from sklearn.model_selection import train_test_split as TTS 
from sklearn.model_selection import GridSearchCV, cross_val_score
from statsmodels.stats.outliers_influence import variance_inflation_factor
from imblearn.over_sampling import SMOTE

#metrics
from sklearn import metrics
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import r2_score,mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score, confusion_matrix, roc_curve, roc_auc_score
from sklearn.metrics import classification_report
from sklearn.metrics import plot_roc_curve

from sklearn import datasets 



#ML models
from sklearn import model_selection
from sklearn.ensemble import RandomForestClassifier,ExtraTreesClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier, AdaBoostClassifier, BaggingClassifier
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier




import joblib
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Loading the dataset

# %%
df = pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset3/main/weatherAUS.csv')
df
# Out:
#             Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0     2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1     2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2     2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3     2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4     2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
# ...          ...      ...      ...      ...       ...          ...       ...
# 8420  2017-06-21    Uluru      2.8     23.4       0.0          NaN       NaN
# 8421  2017-06-22    Uluru      3.6     25.3       0.0          NaN       NaN
# 8422  2017-06-23    Uluru      5.4     26.9       0.0          NaN       NaN
# 8423  2017-06-24    Uluru      7.8     27.0       0.0          NaN       NaN
# 8424  2017-06-25    Uluru     14.9      NaN       0.0          NaN       NaN
#
#      WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0              W           44.0          W  ...        71.0         22.0
# 1            WNW           44.0        NNW  ...        44.0         25.0
# 2            WSW           46.0          W  ...        38.0         30.0
# 3             NE           24.0         SE  ...        45.0         16.0
# 4              W           41.0        ENE  ...        82.0         33.0
# ...          ...            ...        ...  ...         ...          ...
# 8420           E           31.0         SE  ...        51.0         24.0
# 8421         NNW           22.0         SE  ...        56.0         21.0
# 8422           N           37.0         SE  ...        53.0         24.0
# 8423          SE           28.0        SSE  ...        51.0         24.0
# 8424         NaN            NaN        ESE  ...        62.0         36.0
#
#       Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# 0          1007.7       1007.1       8.0       NaN     16.9     21.8
# 1          1010.6       1007.8       NaN       NaN     17.2     24.3
# 2          1007.6       1008.7       NaN       2.0     21.0     23.2
# 3          1017.6       1012.8       NaN       NaN     18.1     26.5
# 4          1010.8       1006.0       7.0       8.0     17.8     29.7
# ...           ...          ...       ...       ...      ...      ...
# 8420       1024.6       1020.3       NaN       NaN     10.1     22.4
# 8421       1023.5       1019.1       NaN       NaN     10.9     24.5
# 8422       1021.0       1016.8       NaN       NaN     12.5     26.1
# 8423       1019.4       1016.5       3.0       2.0     15.1     26.0
# 8424       1020.2       1017.9       8.0       8.0     15.0     20.9
#
#       RainToday  RainTomorrow
# 0            No            No
# 1            No            No
# 2            No            No
# 3            No            No
# 4            No            No
# ...         ...           ...
# 8420         No            No
# 8421         No            No
# 8422         No            No
# 8423         No            No
# 8424         No           NaN
#
# [8425 rows x 23 columns]

# %%
df.head(10)
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
# 5  2008-12-06   Albury     14.6     29.7       0.2          NaN       NaN
# 6  2008-12-07   Albury     14.3     25.0       0.0          NaN       NaN
# 7  2008-12-08   Albury      7.7     26.7       0.0          NaN       NaN
# 8  2008-12-09   Albury      9.7     31.9       0.0          NaN       NaN
# 9  2008-12-10   Albury     13.1     30.1       1.4          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
# 5         WNW           56.0          W  ...        55.0         23.0
# 6           W           50.0         SW  ...        49.0         19.0
# 7           W           35.0        SSE  ...        48.0         19.0
# 8         NNW           80.0         SE  ...        42.0          9.0
# 9           W           28.0          S  ...        58.0         27.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0       1007.7       1007.1       8.0       NaN     16.9     21.8         No
# 1       1010.6       1007.8       NaN       NaN     17.2     24.3         No
# 2       1007.6       1008.7       NaN       2.0     21.0     23.2         No
# 3       1017.6       1012.8       NaN       NaN     18.1     26.5         No
# 4       1010.8       1006.0       7.0       8.0     17.8     29.7         No
# 5       1009.2       1005.4       NaN       NaN     20.6     28.9         No
# 6       1009.6       1008.2       1.0       NaN     18.1     24.6         No
# 7       1013.4       1010.1       NaN       NaN     16.3     25.5         No
# 8       1008.9       1003.6       NaN       NaN     18.3     30.2         No
# 9       1007.0       1005.7       NaN       NaN     20.1     28.2        Yes
#
#    RainTomorrow
# 0            No
# 1            No
# 2            No
# 3            No
# 4            No
# 5            No
# 6            No
# 7            No
# 8           Yes
# 9            No
#
# [10 rows x 23 columns]

# %%
df.tail(10)
# Out:
#             Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 8415  2017-06-16    Uluru      5.2     24.3       0.0          NaN       NaN
# 8416  2017-06-17    Uluru      6.4     23.4       0.0          NaN       NaN
# 8417  2017-06-18    Uluru      8.0     20.7       0.0          NaN       NaN
# 8418  2017-06-19    Uluru      7.4     20.6       0.0          NaN       NaN
# 8419  2017-06-20    Uluru      3.5     21.8       0.0          NaN       NaN
# 8420  2017-06-21    Uluru      2.8     23.4       0.0          NaN       NaN
# 8421  2017-06-22    Uluru      3.6     25.3       0.0          NaN       NaN
# 8422  2017-06-23    Uluru      5.4     26.9       0.0          NaN       NaN
# 8423  2017-06-24    Uluru      7.8     27.0       0.0          NaN       NaN
# 8424  2017-06-25    Uluru     14.9      NaN       0.0          NaN       NaN
#
#      WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 8415           E           24.0         SE  ...        53.0         24.0
# 8416         ESE           31.0          S  ...        53.0         25.0
# 8417         ESE           41.0         SE  ...        56.0         32.0
# 8418           E           35.0        ESE  ...        63.0         33.0
# 8419           E           31.0        ESE  ...        59.0         27.0
# 8420           E           31.0         SE  ...        51.0         24.0
# 8421         NNW           22.0         SE  ...        56.0         21.0
# 8422           N           37.0         SE  ...        53.0         24.0
# 8423          SE           28.0        SSE  ...        51.0         24.0
# 8424         NaN            NaN        ESE  ...        62.0         36.0
#
#       Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# 8415       1023.8       1020.0       NaN       NaN     12.3     23.3
# 8416       1025.8       1023.0       NaN       NaN     11.2     23.1
# 8417       1028.1       1024.3       NaN       7.0     11.6     20.0
# 8418       1027.2       1023.3       NaN       NaN     11.0     20.3
# 8419       1024.7       1021.2       NaN       NaN      9.4     20.9
# 8420       1024.6       1020.3       NaN       NaN     10.1     22.4
# 8421       1023.5       1019.1       NaN       NaN     10.9     24.5
# 8422       1021.0       1016.8       NaN       NaN     12.5     26.1
# 8423       1019.4       1016.5       3.0       2.0     15.1     26.0
# 8424       1020.2       1017.9       8.0       8.0     15.0     20.9
#
#       RainToday  RainTomorrow
# 8415         No            No
# 8416         No            No
# 8417         No            No
# 8418         No            No
# 8419         No            No
# 8420         No            No
# 8421         No            No
# 8422         No            No
# 8423         No            No
# 8424         No           NaN
#
# [10 rows x 23 columns]

# %% [markdown]
# ## Data Features

# %% [markdown]
# **Features and Label**
# - Date  - The date of observation
# - Location  -The common name of the location of the weather station
# - MinTemp  -The minimum temperature in degrees celsius
# - MaxTemp -The maximum temperature in degrees celsius
# - Rainfall  -The amount of rainfall recorded for the day in mm
# - Evaporation  -The so-called Class A pan evaporation (mm) in the 24 hours to 9am
# - Sunshine  -The number of hours of bright sunshine in the day.
# - WindGustDi r- The direction of the strongest wind gust in the 24 hours to midnight
# - WindGustSpeed -The speed (km/h) of the strongest wind gust in the 24 hours to midnight
# - WindDir9am -Direction of the wind at 9am
# - WindDir3pm -Direction of the wind at 3pm
# - WindSpeed9am -Wind speed (km/hr) averaged over 10 minutes prior to 9am
# - WindSpeed3pm -Wind speed (km/hr) averaged over 10 minutes prior to 3pm
# - Humidity9am -Humidity (percent) at 9am
# - Humidity3pm -Humidity (percent) at 3pm
# - Pressure9am -Atmospheric pressure (hpa) reduced to mean sea level at 9am
# - Pressure3pm -Atmospheric pressure (hpa) reduced to mean sea level at 3pm
# - Cloud9am - Fraction of sky obscured by cloud at 9am.
# - Cloud3pm -Fraction of sky obscured by cloud
# - Temp9am-Temperature (degrees C) at 9am
# - Temp3pm -Temperature (degrees C) at 3pm
# - RainToday -Boolean: 1 if precipitation (mm) in the 24 hours to 9am exceeds 1mm, otherwise 0
# - RainTomorrow -The amount of next day rain in mm. Used to create response variable . A kind of measure of the "risk".

# %% [markdown]
# ## EDA

# %%
df.shape
# Out:
# (8425, 23)

# %%
df.columns
# Out:
# Index(['Date', 'Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation',
#        'Sunshine', 'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RainTomorrow'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8425 entries, 0 to 8424
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           8425 non-null   object
#  1   Location       8425 non-null   object
#  2   MinTemp        8350 non-null   float64
#  3   MaxTemp        8365 non-null   float64
#  4   Rainfall       8185 non-null   float64
#  5   Evaporation    4913 non-null   float64
#  6   Sunshine       4431 non-null   float64
#  7   WindGustDir    7434 non-null   object
#  8   WindGustSpeed  7434 non-null   float64
#  9   WindDir9am     7596 non-null   object
#  10  WindDir3pm     8117 non-null   object
#  11  WindSpeed9am   8349 non-null   float64
#  12  WindSpeed3pm   8318 non-null   float64
#  13  Humidity9am    8366 non-null   float64
#  14  Humidity3pm    8323 non-null   float64
#  15  Pressure9am    7116 non-null   float64
#  16  Pressure3pm    7113 non-null   float64
#  17  Cloud9am       6004 non-null   float64
#  18  Cloud3pm       5970 non-null   float64
#  19  Temp9am        8369 non-null   float64
#  20  Temp3pm        8329 non-null   float64
#  21  RainToday      8185 non-null   object
#  22  RainTomorrow   8186 non-null   object
# dtypes: float64(16), object(7)
# memory usage: 1.5+ MB

# %%
df.nunique()
# Out:
# Date             3004
# Location           12
# MinTemp           285
# MaxTemp           331
# Rainfall          250
# Evaporation       116
# Sunshine          140
# WindGustDir        16
# WindGustSpeed      52
# WindDir9am         16
# WindDir3pm         16
# WindSpeed9am       34
# WindSpeed3pm       35
# Humidity9am        90
# Humidity3pm        94
# Pressure9am       384
# Pressure3pm       374
# Cloud9am            9
# Cloud3pm            9
# Temp9am           304
# Temp3pm           328
# RainToday           2
# RainTomorrow        2
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Date                0
# Location            0
# MinTemp            75
# MaxTemp            60
# Rainfall          240
# Evaporation      3512
# Sunshine         3994
# WindGustDir       991
# WindGustSpeed     991
# WindDir9am        829
# WindDir3pm        308
# WindSpeed9am       76
# WindSpeed3pm      107
# Humidity9am        59
# Humidity3pm       102
# Pressure9am      1309
# Pressure3pm      1312
# Cloud9am         2421
# Cloud3pm         2455
# Temp9am            56
# Temp3pm            96
# RainToday         240
# RainTomorrow      239
# dtype: int64

# %% [markdown]
# `Except date and location, every column has some null values`

# %%
for i in df.columns:
    print(df[i].value_counts())
    print('\n'*2)
# Out:
# 2011-01-31    5
# 2011-05-08    5
# 2011-05-21    5
# 2011-05-20    5
# 2011-05-19    5
#              ..
# 2013-01-28    1
# 2013-01-29    1
# 2013-01-30    1
# 2013-01-31    1
# 2013-06-08    1
# Name: Date, Length: 3004, dtype: int64
#
#
#
# Melbourne       1622
# Williamtown     1230
# PerthAirport    1204
# Albury           907
# Newcastle        822
# CoffsHarbour     611
# Brisbane         579
# Penrith          482
# Wollongong       474
# Darwin           250
# Adelaide         205
# Uluru             39
# Name: Location, dtype: int64
#
#
#
#  12.0    74
#  13.2    71
#  13.8    69
#  12.7    68
#  16.4    67
#          ..
#  0.3      1
#  28.3     1
# -1.1      1
# -1.4      1
#  26.0     1
# Name: MinTemp, Length: 285, dtype: int64
#
#
#
# 19.0    87
# 23.8    75
# 19.8    74
# 25.0    71
# 22.0    68
#         ..
# 11.2     1
# 43.1     1
# 42.7     1
# 42.9     1
# 43.5     1
# Name: MaxTemp, Length: 331, dtype: int64
#
#
#
# 0.0      5299
# 0.2       406
# 0.4       177
# 0.6       116
# 1.2        86
#          ...
# 61.2        1
# 128.0       1
# 90.0        1
# 34.4        1
# 40.0        1
# Name: Rainfall, Length: 250, dtype: int64
#
#
#
# 4.0     180
# 3.0     163
# 2.4     147
# 2.2     146
# 2.6     143
#        ...
# 17.0      1
# 18.6      1
# 22.4      1
# 19.2      1
# 0.7       1
# Name: Evaporation, Length: 116, dtype: int64
#
#
#
# 0.0     166
# 11.1     68
# 11.2     67
# 11.0     66
# 10.7     64
#        ...
# 2.5       8
# 13.6      7
# 13.8      4
# 13.9      3
# 13.5      2
# Name: Sunshine, Length: 140, dtype: int64
#
#
#
# N      713
# SSE    578
# S      577
# SW     572
# E      557
# WNW    531
# W      507
# WSW    504
# SE     484
# ENE    415
# SSW    396
# NW     383
# NE     353
# NNE    343
# ESE    302
# NNW    219
# Name: WindGustDir, dtype: int64
#
#
#
# 39.0     441
# 35.0     435
# 37.0     422
# 33.0     408
# 31.0     396
# 41.0     371
# 30.0     367
# 28.0     332
# 43.0     302
# 48.0     292
# 26.0     275
# 50.0     259
# 46.0     258
# 24.0     255
# 52.0     249
# 44.0     241
# 22.0     223
# 54.0     210
# 20.0     186
# 56.0     153
# 57.0     148
# 19.0     137
# 61.0     114
# 59.0     113
# 63.0      95
# 17.0      92
# 65.0      74
# 67.0      64
# 72.0      62
# 15.0      58
# 13.0      57
# 74.0      54
# 70.0      53
# 69.0      49
# 76.0      44
# 78.0      23
# 80.0      22
# 11.0      18
# 85.0      14
# 81.0      13
# 91.0      12
# 93.0       7
# 89.0       7
# 83.0       6
# 9.0        6
# 98.0       4
# 94.0       3
# 87.0       3
# 7.0        2
# 102.0      2
# 100.0      2
# 107.0      1
# Name: WindGustSpeed, dtype: int64
#
#
#
# N      906
# SW     704
# NW     625
# WSW    543
# SE     505
# WNW    480
# SSW    467
# ENE    433
# NNE    430
# W      414
# NE     409
# S      402
# E      380
# SSE    365
# NNW    280
# ESE    253
# Name: WindDir9am, dtype: int64
#
#
#
# SE     813
# S      742
# SSE    623
# WSW    580
# NE     544
# N      524
# SW     494
# WNW    487
# NW     468
# W      462
# ESE    462
# E      460
# ENE    417
# SSW    370
# NNE    365
# NNW    306
# Name: WindDir3pm, dtype: int64
#
#
#
# 9.0     803
# 0.0     752
# 13.0    708
# 4.0     610
# 11.0    607
# 7.0     572
# 6.0     515
# 17.0    481
# 15.0    467
# 19.0    430
# 20.0    427
# 24.0    312
# 22.0    279
# 2.0     258
# 28.0    229
# 26.0    208
# 31.0    153
# 30.0    114
# 35.0     77
# 33.0     70
# 37.0     58
# 41.0     49
# 39.0     35
# 44.0     29
# 43.0     28
# 46.0     26
# 52.0     16
# 50.0     10
# 56.0      8
# 54.0      6
# 48.0      6
# 61.0      2
# 57.0      2
# 63.0      2
# Name: WindSpeed9am, dtype: int64
#
#
#
# 9.0     724
# 19.0    639
# 13.0    599
# 20.0    594
# 17.0    555
# 11.0    534
# 15.0    524
# 24.0    511
# 28.0    458
# 22.0    457
# 26.0    378
# 7.0     331
# 4.0     287
# 30.0    279
# 31.0    266
# 6.0     240
# 0.0     199
# 33.0    170
# 35.0    137
# 37.0    125
# 39.0     80
# 2.0      58
# 41.0     45
# 43.0     34
# 46.0     29
# 44.0     18
# 50.0     12
# 48.0     11
# 52.0      9
# 56.0      7
# 54.0      2
# 61.0      2
# 57.0      2
# 65.0      1
# 83.0      1
# Name: WindSpeed3pm, dtype: int64
#
#
#
# 73.0    205
# 62.0    202
# 68.0    199
# 74.0    195
# 70.0    188
#        ...
# 17.0      2
# 14.0      2
# 11.0      2
# 10.0      1
# 15.0      1
# Name: Humidity9am, Length: 90, dtype: int64
#
#
#
# 55.0    195
# 48.0    194
# 51.0    194
# 46.0    193
# 54.0    193
#        ...
# 8.0      11
# 7.0       9
# 98.0      7
# 99.0      3
# 6.0       3
# Name: Humidity3pm, Length: 94, dtype: int64
#
#
#
# 1014.8    58
# 1019.2    55
# 1016.1    54
# 1019.6    53
# 1020.0    49
#           ..
# 1037.3     1
# 997.8      1
# 1036.9     1
# 1036.3     1
# 1033.6     1
# Name: Pressure9am, Length: 384, dtype: int64
#
#
#
# 1017.8    60
# 1018.0    57
# 1019.8    53
# 1017.9    53
# 1015.5    52
#           ..
# 982.9      1
# 994.3      1
# 998.9      1
# 1030.0     1
# 1029.5     1
# Name: Pressure3pm, Length: 374, dtype: int64
#
#
#
# 7.0    1418
# 1.0    1038
# 8.0    1015
# 0.0     554
# 6.0     551
# 5.0     414
# 3.0     384
# 2.0     357
# 4.0     273
# Name: Cloud9am, dtype: int64
#
#
#
# 7.0    1294
# 1.0    1077
# 8.0     863
# 6.0     597
# 5.0     522
# 2.0     508
# 3.0     411
# 4.0     351
# 0.0     347
# Name: Cloud3pm, dtype: int64
#
#
#
# 14.8    77
# 18.0    73
# 18.3    71
# 17.5    69
# 20.6    68
#         ..
# 2.5      1
# 2.0      1
# 3.4      1
# 5.2      1
# 30.2     1
# Name: Temp9am, Length: 304, dtype: int64
#
#
#
# 19.2    78
# 22.5    77
# 19.0    75
# 21.7    72
# 18.5    72
#         ..
# 37.4     1
# 8.7      1
# 36.7     1
# 8.6      1
# 42.4     1
# Name: Temp3pm, Length: 328, dtype: int64
#
#
#
# No     6195
# Yes    1990
# Name: RainToday, dtype: int64
#
#
#
# No     6195
# Yes    1991
# Name: RainTomorrow, dtype: int64

# %%
df['RainTomorrow'].value_counts()
# Out:
# No     6195
# Yes    1991
# Name: RainTomorrow, dtype: int64

# %% [markdown]
# `There is clear imbalance in the target - for the classification problem and will need to be fixed using SMOTE`

# %% [markdown]
# ## Feature Engineering

# %%
df.dtypes
# Out:
# Date              object
# Location          object
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir       object
# WindGustSpeed    float64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am     float64
# WindSpeed3pm     float64
# Humidity9am      float64
# Humidity3pm      float64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am         float64
# Cloud3pm         float64
# Temp9am          float64
# Temp3pm          float64
# RainToday         object
# RainTomorrow      object
# dtype: object

# %% [markdown]
# **Date column is appearing as object. We need to convert it into date type.**

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %% [markdown]
# **Now we need to extract the day, month and year separately from the date for model building**

# %%
df['Day'] = pd.to_datetime(df.Date,format="%d/%m/%Y").dt.day
df['Month'] = pd.to_datetime(df.Date, format="%d/%m/%Y").dt.month
df['Year'] = pd.to_datetime(df.Date, format="%d/%m/%Y").dt.year

# %%
df.drop(columns=['Date'],axis=1,inplace=True)

# %%
df.head(10)
# Out:
#   Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0   Albury     13.4     22.9       0.6          NaN       NaN           W
# 1   Albury      7.4     25.1       0.0          NaN       NaN         WNW
# 2   Albury     12.9     25.7       0.0          NaN       NaN         WSW
# 3   Albury      9.2     28.0       0.0          NaN       NaN          NE
# 4   Albury     17.5     32.3       1.0          NaN       NaN           W
# 5   Albury     14.6     29.7       0.2          NaN       NaN         WNW
# 6   Albury     14.3     25.0       0.0          NaN       NaN           W
# 7   Albury      7.7     26.7       0.0          NaN       NaN           W
# 8   Albury      9.7     31.9       0.0          NaN       NaN         NNW
# 9   Albury     13.1     30.1       1.4          NaN       NaN           W
#
#    WindGustSpeed WindDir9am WindDir3pm  ...  Pressure3pm  Cloud9am  Cloud3pm  \
# 0           44.0          W        WNW  ...       1007.1       8.0       NaN
# 1           44.0        NNW        WSW  ...       1007.8       NaN       NaN
# 2           46.0          W        WSW  ...       1008.7       NaN       2.0
# 3           24.0         SE          E  ...       1012.8       NaN       NaN
# 4           41.0        ENE         NW  ...       1006.0       7.0       8.0
# 5           56.0          W          W  ...       1005.4       NaN       NaN
# 6           50.0         SW          W  ...       1008.2       1.0       NaN
# 7           35.0        SSE          W  ...       1010.1       NaN       NaN
# 8           80.0         SE         NW  ...       1003.6       NaN       NaN
# 9           28.0          S        SSE  ...       1005.7       NaN       NaN
#
#    Temp9am  Temp3pm  RainToday  RainTomorrow  Day  Month  Year
# 0     16.9     21.8         No            No    1     12  2008
# 1     17.2     24.3         No            No    2     12  2008
# 2     21.0     23.2         No            No    3     12  2008
# 3     18.1     26.5         No            No    4     12  2008
# 4     17.8     29.7         No            No    5     12  2008
# 5     20.6     28.9         No            No    6     12  2008
# 6     18.1     24.6         No            No    7     12  2008
# 7     16.3     25.5         No            No    8     12  2008
# 8     18.3     30.2         No           Yes    9     12  2008
# 9     20.1     28.2        Yes            No   10     12  2008
#
# [10 rows x 25 columns]

# %%
df.tail(10)
# Out:
#      Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 8415    Uluru      5.2     24.3       0.0          NaN       NaN           E
# 8416    Uluru      6.4     23.4       0.0          NaN       NaN         ESE
# 8417    Uluru      8.0     20.7       0.0          NaN       NaN         ESE
# 8418    Uluru      7.4     20.6       0.0          NaN       NaN           E
# 8419    Uluru      3.5     21.8       0.0          NaN       NaN           E
# 8420    Uluru      2.8     23.4       0.0          NaN       NaN           E
# 8421    Uluru      3.6     25.3       0.0          NaN       NaN         NNW
# 8422    Uluru      5.4     26.9       0.0          NaN       NaN           N
# 8423    Uluru      7.8     27.0       0.0          NaN       NaN          SE
# 8424    Uluru     14.9      NaN       0.0          NaN       NaN         NaN
#
#       WindGustSpeed WindDir9am WindDir3pm  ...  Pressure3pm  Cloud9am  \
# 8415           24.0         SE          E  ...       1020.0       NaN
# 8416           31.0          S        ESE  ...       1023.0       NaN
# 8417           41.0         SE          E  ...       1024.3       NaN
# 8418           35.0        ESE          E  ...       1023.3       NaN
# 8419           31.0        ESE          E  ...       1021.2       NaN
# 8420           31.0         SE        ENE  ...       1020.3       NaN
# 8421           22.0         SE          N  ...       1019.1       NaN
# 8422           37.0         SE        WNW  ...       1016.8       NaN
# 8423           28.0        SSE          N  ...       1016.5       3.0
# 8424            NaN        ESE        ESE  ...       1017.9       8.0
#
#       Cloud3pm  Temp9am  Temp3pm  RainToday  RainTomorrow  Day  Month  Year
# 8415       NaN     12.3     23.3         No            No   16      6  2017
# 8416       NaN     11.2     23.1         No            No   17      6  2017
# 8417       7.0     11.6     20.0         No            No   18      6  2017
# 8418       NaN     11.0     20.3         No            No   19      6  2017
# 8419       NaN      9.4     20.9         No            No   20      6  2017
# 8420       NaN     10.1     22.4         No            No   21      6  2017
# 8421       NaN     10.9     24.5         No            No   22      6  2017
# 8422       NaN     12.5     26.1         No            No   23      6  2017
# 8423       2.0     15.1     26.0         No            No   24      6  2017
# 8424       8.0     15.0     20.9         No           NaN   25      6  2017
#
# [10 rows x 25 columns]

# %% [markdown]
# **Treating the null values in each column**

# %%
df['MinTemp'] = df['MinTemp'].fillna(df['MinTemp'].mean())

df['MaxTemp'] = df['MaxTemp'].fillna(df['MaxTemp'].mean())

df['Rainfall'] = df['Rainfall'].fillna(df['Rainfall'].mode()[0])

df['Evaporation'] = df['Evaporation'].fillna(df['Evaporation'].mean())

df['Sunshine'] = df['Sunshine'].fillna(df['Sunshine'].mean())

df['RainTomorrow'] = df['RainTomorrow'].fillna(df['RainTomorrow'].mode()[0])

df['RainToday'] = df['RainToday'].fillna(df['RainToday'].mode()[0])

df['Temp3pm'] = df['Temp3pm'].fillna(df['Temp3pm'].mean())

df['Temp3pm'] = df['Temp3pm'].fillna(df['Temp3pm'].mean())

df['Temp9am'] = df['Temp9am'].fillna(df['Temp9am'].mean())

df['Cloud3pm'] = df['Cloud3pm'].fillna(df['Cloud3pm'].mean())

df['Cloud9am'] = df['Cloud9am'].fillna(df['Cloud9am'].mean())

df['Pressure3pm'] = df['Pressure3pm'].fillna(df['Pressure3pm'].mean())

df['Pressure9am'] = df['Pressure9am'].fillna(df['Pressure9am'].mean())

df['Humidity3pm'] = df['Humidity3pm'].fillna(df['Humidity3pm'].mean())

df['Humidity9am'] = df['Humidity9am'].fillna(df['Humidity9am'].mean())

df['WindSpeed3pm'] = df['WindSpeed3pm'].fillna(df['WindSpeed3pm'].mean())

df['WindSpeed9am'] = df['WindSpeed9am'].fillna(df['WindSpeed9am'].mean())

df['WindDir3pm'] = df['WindDir3pm'].fillna(df['WindDir3pm'].mode()[0])

df['WindDir9am'] = df['WindDir9am'].fillna(df['WindDir9am'].mode()[0])

df['WindGustSpeed'] = df['WindGustSpeed'].fillna(df['WindGustSpeed'].mean())

df['WindGustDir'] = df['WindGustDir'].fillna(df['WindGustDir'].mode()[0])

# %%
df.isnull().sum()
# Out:
# Location         0
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# RainTomorrow     0
# Day              0
# Month            0
# Year             0
# dtype: int64

# %% [markdown]
# `Null values have been removed and fixed`

# %%
df.describe()
# Out:
#            MinTemp      MaxTemp     Rainfall  Evaporation     Sunshine  \
# count  8425.000000  8425.000000  8425.000000  8425.000000  8425.000000
# mean     13.193305    23.859976     2.725982     5.389395     7.632205
# std       5.379488     6.114516    10.319872     3.852004     2.825451
# min      -2.000000     8.200000     0.000000     0.000000     0.000000
# 25%       9.300000    19.300000     0.000000     4.000000     7.632205
# 50%      13.200000    23.300000     0.000000     5.389395     7.632205
# 75%      17.300000    28.000000     0.800000     5.389395     8.900000
# max      28.500000    45.500000   371.000000   145.000000    13.900000
#
#        WindGustSpeed  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# count    8425.000000   8425.000000   8425.000000  8425.000000  8425.000000
# mean       40.174469     13.847646     18.533662    67.822496    51.249790
# std        13.776101     10.128579      9.704759    16.774231    18.311894
# min         7.000000      0.000000      0.000000    10.000000     6.000000
# 25%        31.000000      6.000000     11.000000    56.000000    39.000000
# 50%        40.174469     13.000000     19.000000    68.000000    51.000000
# 75%        48.000000     20.000000     24.000000    80.000000    63.000000
# max       107.000000     63.000000     83.000000   100.000000    99.000000
#
#        Pressure9am  Pressure3pm     Cloud9am     Cloud3pm      Temp9am  \
# count  8425.000000  8425.000000  8425.000000  8425.000000  8425.000000
# mean   1017.640233  1015.236075     4.566622     4.503183    17.762015
# std       6.275759     6.217451     2.429205     2.299419     5.608301
# min     989.800000   982.900000     0.000000     0.000000     1.900000
# 25%    1014.000000  1011.400000     3.000000     3.000000    13.800000
# 50%    1017.640233  1015.236075     4.566622     4.503183    17.762015
# 75%    1021.300000  1018.800000     7.000000     7.000000    21.900000
# max    1039.000000  1036.000000     8.000000     8.000000    39.400000
#
#            Temp3pm          Day        Month         Year
# count  8425.000000  8425.000000  8425.000000  8425.000000
# mean     22.442934    15.741958     6.442136  2012.102433
# std       5.945849     8.787354     3.437994     2.473137
# min       7.300000     1.000000     1.000000  2008.000000
# 25%      18.100000     8.000000     3.000000  2010.000000
# 50%      22.000000    16.000000     6.000000  2011.000000
# 75%      26.300000    23.000000     9.000000  2014.000000
# max      44.100000    31.000000    12.000000  2017.000000

# %% [markdown]
# - `mean and median are quite close to each other for several columns, implying low skewness`
# - `mean and median are varying in some columns, implying skewness`
# - `difference between 75% and max shows the presence of outliers`

# %% [markdown]
# ## Data Visualization

# %%
#Categorical Columns
cat_col=[]
for i in df.dtypes.index:
    if df.dtypes[i]=='object':
        cat_col.append(i)
print(cat_col)
# Out:
# ['Location', 'WindGustDir', 'WindDir9am', 'WindDir3pm', 'RainToday', 'RainTomorrow']

# %%
#numerical Collumns
num_col=[]
for i in df.dtypes.index:
    if df.dtypes[i]!='object':
        num_col.append(i)
print(num_col)
# Out:
# ['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine', 'WindGustSpeed', 'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm', 'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am', 'Temp3pm', 'Day', 'Month', 'Year']

# %%
plt.figure(figsize=(10,5))
sns.countplot(df["Location"])
plt.title("Count of Locations")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# - `highest rainfall in Melbourne, followed by Williamtown, Perth Airport, Albury and Newcastle`
# - `lowest rainfall in Uluru, followed by Darwin and Adelaide`

# %%
plt.figure(figsize=(10,5))
sns.countplot(df["WindGustDir"])
plt.title("Strongest wind gust in the 24 hours")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# `Strongest wind direction is N and the weakest is NNW`

# %%
plt.figure(figsize=(15,5))
plt.subplot(1, 2, 1)
plt.title('Direction of the wind at 9am')
sns.countplot(df['WindDir9am'])
plt.subplot(1,2,2)
plt.title('Direction of the wind at 3pm')
sns.countplot(df['WindDir3pm'])
plt.show()

# %% [markdown]
# - `wind direction at 9 am strongest - N`
# - `wind direction at 3 pm strongest - SE`

# %%
plt.figure(figsize=(10,5))
plt.subplot(1, 2, 1)
plt.title('RainToday')
sns.countplot(df['RainToday'],palette='plasma')
plt.subplot(1,2,2)
plt.title('RainTomorrow')
sns.countplot(df['RainTomorrow'], palette='plasma')
plt.show()

# %% [markdown]
# `No significant comparable insights`

# %%
# distribution across numerical columns
plt.figure(figsize=(20,25))
plotnumber=1
for column in num_col:
    if plotnumber<=20:
        ax=plt.subplot(7,3,plotnumber)
        sns.distplot(df[column],color="b")
        plt.xlabel(column,fontsize=10)
        plt.yticks(rotation=0,fontsize=10)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# **Skewed to the right**
# - max temp
# - rainfall
# - evaporation
# - WindGustSpeed
# - WindSpeed9am
# - WindSpeed3pm
#
# **Distribution not normal**
# - Sunshine

# %%
plt.figure(figsize=(15,5))
plt.subplot(1, 2, 1)
plt.title('RainTomorrow')
sns.scatterplot(x='RainTomorrow',y='Location',data=df)
plt.subplot(1,2,2)
plt.title('Rainfall')
sns.scatterplot(x='Rainfall',y='Location',data=df)
plt.show()

# %% [markdown]
# `Location does not have major impact on rainfall or whther it will rain tomorrow`

# %%
fig,axes=plt.subplots(2,2,figsize=(15,10))

sns.scatterplot(x='MinTemp',y='RainTomorrow',ax=axes[0,0],data=df)
sns.scatterplot(x='MaxTemp',y='RainTomorrow',ax=axes[0,1],data=df)
sns.scatterplot(x='MinTemp',y='Rainfall',ax=axes[1,0],data=df)
sns.scatterplot(x='MaxTemp',y='Rainfall',ax=axes[1,1],data=df)
# Out:
# <AxesSubplot:xlabel='MaxTemp', ylabel='Rainfall'>

# %% [markdown]
# - `Temp (min and max) has no relation with RainTomorrow`
# - `Some relation between temperature and rainfall`

# %%
fig,axes=plt.subplots(2,2,figsize=(15,10))

sns.lineplot(x='Evaporation',y='RainTomorrow',ax=axes[0,0],data=df)
sns.lineplot(x='Sunshine',y='RainTomorrow',ax=axes[0,1],data=df)
sns.lineplot(x='Evaporation',y='Rainfall',ax=axes[1,0],data=df)
sns.lineplot(x='Sunshine',y='Rainfall',ax=axes[1,1],data=df)
# Out:
# <AxesSubplot:xlabel='Sunshine', ylabel='Rainfall'>

# %% [markdown]
# - `Evaporation has a strong relationship with whether it will rain tomorrow, as well as the amount of rainfall`
# - `Lower sunshine -> possibility of rain tomorrow`
# - `lower sunshine -> higher rain to some extent`

# %%
fig,axes=plt.subplots(2,2,figsize=(15,10))

sns.lineplot(x='Humidity9am',y='RainTomorrow',ax=axes[0,0],data=df)
sns.lineplot(x='Humidity3pm',y='RainTomorrow',ax=axes[0,1],data=df)
sns.lineplot(x='Humidity9am',y='Rainfall',ax=axes[1,0],data=df)
sns.lineplot(x='Humidity3pm',y='Rainfall',ax=axes[1,1],data=df)
# Out:
# <AxesSubplot:xlabel='Humidity3pm', ylabel='Rainfall'>

# %% [markdown]
# - `higher humidity -> more chance of rain tomorrow`
# - `higher humidity -> more rainfall`

# %%
fig,axes=plt.subplots(2,2,figsize=(15,10))

sns.lineplot(x='Cloud9am',y='RainTomorrow',ax=axes[0,0],data=df)
sns.lineplot(x='Cloud3pm',y='RainTomorrow',ax=axes[0,1],data=df)
sns.lineplot(x='Cloud9am',y='Rainfall',ax=axes[1,0],data=df)
sns.lineplot(x='Cloud3pm',y='Rainfall',ax=axes[1,1],data=df)
# Out:
# <AxesSubplot:xlabel='Cloud3pm', ylabel='Rainfall'>

# %% [markdown]
# - `higher cloud coverage -> more chance of rain tomorrow`
# - `higher cloud coverage -> more amount of rainfall`

# %%
fig,axes=plt.subplots(2,3,figsize=(15,10))

sns.lineplot(x='Day',y='RainTomorrow',ax=axes[0,0],data=df)
sns.lineplot(x='Month',y='RainTomorrow',ax=axes[0,1],data=df)
sns.lineplot(x='Year',y='RainTomorrow',ax=axes[0,2],data=df)

sns.lineplot(x='Day',y='Rainfall',ax=axes[1,0],data=df)
sns.lineplot(x='Month',y='Rainfall',ax=axes[1,1],data=df)
sns.lineplot(x='Year',y='Rainfall',ax=axes[1,2],data=df)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Rainfall'>

# %% [markdown]
# `No linear relationship / trend is visible with the possibility of rain tomorrow or the amount of rainfall. It keeps varying. Higher rainfall in April, November and June`

# %% [markdown]
# ## Outlier Check

# %%
plt.figure(figsize=(15,10))
plotnumber=1
for column in num_col:
    if plotnumber<=20:
        ax=plt.subplot(3,7,plotnumber)
        sns.boxplot(df[column],color="b")
        plt.xlabel(column,fontsize=15)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# **Presence of outliers:**
# - MaxTemp
# - Rainfall (mainly because a lot of the data is 0)
# - Evaporation (mainly because a lot of the data is 0)
# - Sunshine
# - WindGustSpeed
# - WindSpeed9am
# - WindSpeed3pm
# - Humidity9am
# - Pressure9am
# - Pressure3pm
# - Temp9am
# - Temp3pm

# %%
feature = df[['MaxTemp',
              'Rainfall',
              'Evaporation',
              'Sunshine',
              'WindGustSpeed',
              'WindSpeed9am',
              'WindSpeed3pm',
              'Humidity9am',
              'Pressure9am',
              'Pressure3pm',
              'Temp9am',
              'Temp3pm']]

z=np.abs(zscore(feature))
z
# Out:
#            MaxTemp  Rainfall   Evaporation      Sunshine  WindGustSpeed  \
# 0     1.570089e-01  0.206021  2.305893e-16  1.257472e-15       0.277710
# 1     2.028121e-01  0.264165  2.305893e-16  1.257472e-15       0.277710
# 2     3.009450e-01  0.264165  2.305893e-16  1.257472e-15       0.422897
# 3     6.771214e-01  0.264165  2.305893e-16  1.257472e-15       1.174166
# 4     1.380408e+00  0.167258  2.305893e-16  1.257472e-15       0.059928
# ...            ...       ...           ...           ...            ...
# 8420  7.523137e-02  0.264165  2.305893e-16  1.257472e-15       0.666009
# 8421  2.355231e-01  0.264165  2.305893e-16  1.257472e-15       1.319354
# 8422  4.972110e-01  0.264165  2.305893e-16  1.257472e-15       0.230447
# 8423  5.135665e-01  0.264165  2.305893e-16  1.257472e-15       0.883791
# 8424  2.905320e-15  0.264165  2.305893e-16  1.257472e-15       0.000000
#
#       WindSpeed9am  WindSpeed3pm  Humidity9am  Pressure9am  Pressure3pm  \
# 0         0.607461      0.563297     0.189439     1.584003     1.308665
# 1         0.972321      0.357200     1.420268     1.121880     1.196072
# 2         0.508725      0.769394     1.777981     1.599939     1.051309
# 3         0.281166      0.982428     1.360650     0.006411     0.391836
# 4         0.676112      0.151104     0.845246     1.090010     1.485596
# ...            ...           ...          ...          ...          ...
# 8420      0.083694      0.776331     1.002937     1.109058     0.814518
# 8421      0.083694      0.982428     0.704843     0.933770     0.621501
# 8422      0.478639      0.982428     0.883699     0.535388     0.251553
# 8423      0.083694      1.188525     1.002937     0.280424     0.203299
# 8424      0.311252      0.158041     0.347130     0.407906     0.428485
#
#        Temp9am   Temp3pm
# 0     0.153712  0.108138
# 1     0.100217  0.312348
# 2     0.577390  0.127334
# 3     0.060269  0.682376
# 4     0.006773  1.220599
# ...        ...       ...
# 8420  1.366273  0.007221
# 8421  1.223619  0.345987
# 8422  0.938310  0.615099
# 8423  0.474684  0.598279
# 8424  0.492516  0.259513
#
# [8425 rows x 12 columns]

# %%
new_df = df[(z<3).all(axis=1)] 
new_df
# Out:
#      Location  MinTemp    MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0      Albury     13.4  22.900000       0.6     5.389395  7.632205
# 1      Albury      7.4  25.100000       0.0     5.389395  7.632205
# 2      Albury     12.9  25.700000       0.0     5.389395  7.632205
# 3      Albury      9.2  28.000000       0.0     5.389395  7.632205
# 4      Albury     17.5  32.300000       1.0     5.389395  7.632205
# ...       ...      ...        ...       ...          ...       ...
# 8420    Uluru      2.8  23.400000       0.0     5.389395  7.632205
# 8421    Uluru      3.6  25.300000       0.0     5.389395  7.632205
# 8422    Uluru      5.4  26.900000       0.0     5.389395  7.632205
# 8423    Uluru      7.8  27.000000       0.0     5.389395  7.632205
# 8424    Uluru     14.9  23.859976       0.0     5.389395  7.632205
#
#      WindGustDir  WindGustSpeed WindDir9am WindDir3pm  ...  Pressure3pm  \
# 0              W      44.000000          W        WNW  ...       1007.1
# 1            WNW      44.000000        NNW        WSW  ...       1007.8
# 2            WSW      46.000000          W        WSW  ...       1008.7
# 3             NE      24.000000         SE          E  ...       1012.8
# 4              W      41.000000        ENE         NW  ...       1006.0
# ...          ...            ...        ...        ...  ...          ...
# 8420           E      31.000000         SE        ENE  ...       1020.3
# 8421         NNW      22.000000         SE          N  ...       1019.1
# 8422           N      37.000000         SE        WNW  ...       1016.8
# 8423          SE      28.000000        SSE          N  ...       1016.5
# 8424           N      40.174469        ESE        ESE  ...       1017.9
#
#       Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RainTomorrow  Day  \
# 0     8.000000  4.503183     16.9     21.8         No            No    1
# 1     4.566622  4.503183     17.2     24.3         No            No    2
# 2     4.566622  2.000000     21.0     23.2         No            No    3
# 3     4.566622  4.503183     18.1     26.5         No            No    4
# 4     7.000000  8.000000     17.8     29.7         No            No    5
# ...        ...       ...      ...      ...        ...           ...  ...
# 8420  4.566622  4.503183     10.1     22.4         No            No   21
# 8421  4.566622  4.503183     10.9     24.5         No            No   22
# 8422  4.566622  4.503183     12.5     26.1         No            No   23
# 8423  3.000000  2.000000     15.1     26.0         No            No   24
# 8424  8.000000  8.000000     15.0     20.9         No            No   25
#
#       Month  Year
# 0        12  2008
# 1        12  2008
# 2        12  2008
# 3        12  2008
# 4        12  2008
# ...     ...   ...
# 8420      6  2017
# 8421      6  2017
# 8422      6  2017
# 8423      6  2017
# 8424      6  2017
#
# [7987 rows x 25 columns]

# %%
print(df.shape)
print(new_df.shape)
# Out:
# (8425, 25)
# (7987, 25)

# %%
loss = (8425-7987)/8425*100
loss
# Out:
# 5.198813056379822

# %% [markdown]
# `Data loss is 5.19%, which is acceptable`

# %%
new_df.skew().sort_values()
# Out:
# Sunshine        -0.723970
# Cloud9am        -0.356892
# Cloud3pm        -0.266829
# Humidity9am     -0.231656
# MinTemp         -0.084549
# Temp9am         -0.038035
# Day              0.002731
# Pressure9am      0.020735
# Pressure3pm      0.044876
# Month            0.054460
# Humidity3pm      0.125150
# WindSpeed3pm     0.300109
# MaxTemp          0.314510
# Temp3pm          0.334170
# Year             0.430100
# WindGustSpeed    0.506897
# WindSpeed9am     0.711395
# Evaporation      0.846181
# Rainfall         3.519090
# dtype: float64

# %% [markdown]
# `Skewness present in Sunshine, Rainfall, Evaporation, WindSpeed9am, WindGustSpeed`

# %%
new_df["Sunshine"] = np.cbrt(new_df["Sunshine"])
new_df["Rainfall"] = np.cbrt(new_df["Rainfall"])
new_df["Evaporation"] = np.cbrt(new_df["Evaporation"])
new_df["WindSpeed9am"] = np.cbrt(new_df["WindSpeed9am"])
new_df["WindGustSpeed"] = np.cbrt(new_df["WindGustSpeed"])

# %%
new_df.skew().sort_values()
# Out:
# Sunshine        -2.856050
# WindSpeed9am    -1.274070
# Evaporation     -0.967518
# Cloud9am        -0.356892
# Cloud3pm        -0.266829
# Humidity9am     -0.231656
# WindGustSpeed   -0.180704
# MinTemp         -0.084549
# Temp9am         -0.038035
# Day              0.002731
# Pressure9am      0.020735
# Pressure3pm      0.044876
# Month            0.054460
# Humidity3pm      0.125150
# WindSpeed3pm     0.300109
# MaxTemp          0.314510
# Temp3pm          0.334170
# Year             0.430100
# Rainfall         1.473709
# dtype: float64

# %%
plt.figure(figsize=(20,25))
plotnumber=1
for column in num_col:
    if plotnumber<=20:
        ax=plt.subplot(7,3,plotnumber)
        sns.distplot(new_df[column],color="b")
        plt.xlabel(column,fontsize=10)
        plt.yticks(rotation=0,fontsize=10)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# `most of the skewness has been removed`

# %% [markdown]
# ## Encoding categorical data

# %%
le=LabelEncoder()
new_df[cat_col]= new_df[cat_col].apply(le.fit_transform)
new_df
# Out:
#       Location  MinTemp    MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0            1     13.4  22.900000  0.843433     1.753261  1.968868
# 1            1      7.4  25.100000  0.000000     1.753261  1.968868
# 2            1     12.9  25.700000  0.000000     1.753261  1.968868
# 3            1      9.2  28.000000  0.000000     1.753261  1.968868
# 4            1     17.5  32.300000  1.000000     1.753261  1.968868
# ...        ...      ...        ...       ...          ...       ...
# 8420         9      2.8  23.400000  0.000000     1.753261  1.968868
# 8421         9      3.6  25.300000  0.000000     1.753261  1.968868
# 8422         9      5.4  26.900000  0.000000     1.753261  1.968868
# 8423         9      7.8  27.000000  0.000000     1.753261  1.968868
# 8424         9     14.9  23.859976  0.000000     1.753261  1.968868
#
#       WindGustDir  WindGustSpeed  WindDir9am  WindDir3pm  ...  Pressure3pm  \
# 0              13       3.530348          13          14  ...       1007.1
# 1              14       3.530348           6          15  ...       1007.8
# 2              15       3.583048          13          15  ...       1008.7
# 3               4       2.884499           9           0  ...       1012.8
# 4              13       3.448217           1           7  ...       1006.0
# ...           ...            ...         ...         ...  ...          ...
# 8420            0       3.141381           9           1  ...       1020.3
# 8421            6       2.802039           9           3  ...       1019.1
# 8422            3       3.332222           9          14  ...       1016.8
# 8423            9       3.036589          10           3  ...       1016.5
# 8424            3       3.424917           2           2  ...       1017.9
#
#       Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RainTomorrow  Day  \
# 0     8.000000  4.503183     16.9     21.8          0             0    1
# 1     4.566622  4.503183     17.2     24.3          0             0    2
# 2     4.566622  2.000000     21.0     23.2          0             0    3
# 3     4.566622  4.503183     18.1     26.5          0             0    4
# 4     7.000000  8.000000     17.8     29.7          0             0    5
# ...        ...       ...      ...      ...        ...           ...  ...
# 8420  4.566622  4.503183     10.1     22.4          0             0   21
# 8421  4.566622  4.503183     10.9     24.5          0             0   22
# 8422  4.566622  4.503183     12.5     26.1          0             0   23
# 8423  3.000000  2.000000     15.1     26.0          0             0   24
# 8424  8.000000  8.000000     15.0     20.9          0             0   25
#
#       Month  Year
# 0        12  2008
# 1        12  2008
# 2        12  2008
# 3        12  2008
# 4        12  2008
# ...     ...   ...
# 8420      6  2017
# 8421      6  2017
# 8422      6  2017
# 8423      6  2017
# 8424      6  2017
#
# [7987 rows x 25 columns]

# %% [markdown]
# ## Establishing correlation

# %%
corr=new_df.corr()
corr
# Out:
#                Location   MinTemp   MaxTemp  Rainfall  Evaporation  Sunshine  \
# Location       1.000000  0.116694  0.063798  0.013245     0.124033  0.066529
# MinTemp        0.116694  1.000000  0.718598  0.073519     0.356089  0.006387
# MaxTemp        0.063798  0.718598  1.000000 -0.229296     0.459432  0.310907
# Rainfall       0.013245  0.073519 -0.229296  1.000000    -0.169206 -0.208747
# Evaporation    0.124033  0.356089  0.459432 -0.169206     1.000000  0.338895
# Sunshine       0.066529  0.006387  0.310907 -0.208747     0.338895  1.000000
# WindGustDir   -0.037707 -0.154935 -0.237955  0.124172    -0.116632 -0.071328
# WindGustSpeed  0.259483  0.253762  0.155754  0.080302     0.161445  0.006968
# WindDir9am    -0.041030 -0.045231 -0.217160  0.155484    -0.097850 -0.052916
# WindDir3pm    -0.031195 -0.154184 -0.190417  0.113229    -0.039123 -0.045615
# WindSpeed9am   0.210199  0.176329  0.043290  0.015092     0.022884 -0.051943
# WindSpeed3pm   0.231939  0.185976  0.093241  0.020535     0.073783  0.022896
# Humidity9am    0.003725 -0.126383 -0.382687  0.400047    -0.297114 -0.278670
# Humidity3pm    0.059978  0.090208 -0.409560  0.380798    -0.218295 -0.396266
# Pressure9am   -0.024265 -0.433113 -0.333569 -0.108021    -0.253660  0.010170
# Pressure3pm   -0.012288 -0.427936 -0.414358 -0.031431    -0.269824 -0.036453
# Cloud9am       0.041859  0.089354 -0.252579  0.295058    -0.104188 -0.428790
# Cloud3pm       0.027050  0.036649 -0.248268  0.259063    -0.139438 -0.449945
# Temp9am        0.118100  0.888690  0.864864 -0.094134     0.425806  0.177263
# Temp3pm        0.060707  0.687570  0.974957 -0.239093     0.447148  0.325496
# RainToday      0.002934  0.061728 -0.219747  0.903292    -0.167423 -0.188645
# RainTomorrow   0.009222  0.091021 -0.149708  0.322561    -0.087385 -0.287585
# Day           -0.004978  0.010924  0.017068 -0.018118     0.010289  0.000222
# Month         -0.086011 -0.247066 -0.164351 -0.006507    -0.048615  0.000896
# Year           0.481143  0.040001  0.120204  0.007964     0.143626  0.106974
#
#                WindGustDir  WindGustSpeed  WindDir9am  WindDir3pm  ...  \
# Location         -0.037707       0.259483   -0.041030   -0.031195  ...
# MinTemp          -0.154935       0.253762   -0.045231   -0.154184  ...
# MaxTemp          -0.237955       0.155754   -0.217160   -0.190417  ...
# Rainfall          0.124172       0.080302    0.155484    0.113229  ...
# Evaporation      -0.116632       0.161445   -0.097850   -0.039123  ...
# Sunshine         -0.071328       0.006968   -0.052916   -0.045615  ...
# WindGustDir       1.000000      -0.000287    0.405681    0.507292  ...
# WindGustSpeed    -0.000287       1.000000   -0.063555    0.084416  ...
# WindDir9am        0.405681      -0.063555    1.000000    0.243622  ...
# WindDir3pm        0.507292       0.084416    0.243622    1.000000  ...
# WindSpeed9am      0.108659       0.446369    0.217007    0.028427  ...
# WindSpeed3pm      0.108357       0.631783    0.058887    0.079716  ...
# Humidity9am       0.031081      -0.278138    0.009571   -0.007820  ...
# Humidity3pm       0.051061      -0.087611    0.117910   -0.009385  ...
# Pressure9am      -0.095047      -0.371107   -0.003943   -0.129842  ...
# Pressure3pm      -0.008263      -0.328938    0.081400   -0.037280  ...
# Cloud9am          0.123415       0.005673    0.092396    0.073742  ...
# Cloud3pm          0.093527       0.057338    0.062637    0.054321  ...
# Temp9am          -0.185080       0.225777   -0.101576   -0.172000  ...
# Temp3pm          -0.249791       0.121450   -0.224390   -0.202000  ...
# RainToday         0.121709       0.075952    0.149239    0.100983  ...
# RainTomorrow      0.044378       0.169135    0.027091    0.003674  ...
# Day               0.017003      -0.005673   -0.010014   -0.000714  ...
# Month             0.038044       0.047951    0.018344    0.028629  ...
# Year             -0.096042      -0.021156   -0.034468   -0.010781  ...
#
#                Pressure3pm  Cloud9am  Cloud3pm   Temp9am   Temp3pm  RainToday  \
# Location         -0.012288  0.041859  0.027050  0.118100  0.060707   0.002934
# MinTemp          -0.427936  0.089354  0.036649  0.888690  0.687570   0.061728
# MaxTemp          -0.414358 -0.252579 -0.248268  0.864864  0.974957  -0.219747
# Rainfall         -0.031431  0.295058  0.259063 -0.094134 -0.239093   0.903292
# Evaporation      -0.269824 -0.104188 -0.139438  0.425806  0.447148  -0.167423
# Sunshine         -0.036453 -0.428790 -0.449945  0.177263  0.325496  -0.188645
# WindGustDir      -0.008263  0.123415  0.093527 -0.185080 -0.249791   0.121709
# WindGustSpeed    -0.328938  0.005673  0.057338  0.225777  0.121450   0.075952
# WindDir9am        0.081400  0.092396  0.062637 -0.101576 -0.224390   0.149239
# WindDir3pm       -0.037280  0.073742  0.054321 -0.172000 -0.202000   0.100983
# WindSpeed9am     -0.103402 -0.013502  0.025143  0.158467  0.025985   0.032495
# WindSpeed3pm     -0.177395  0.004160 -0.002414  0.190467  0.071548   0.022687
# Humidity9am       0.162504  0.404493  0.301372 -0.369380 -0.376383   0.357752
# Humidity3pm       0.062125  0.416441  0.437228 -0.115275 -0.478797   0.342991
# Pressure9am       0.960079 -0.061322 -0.069925 -0.412416 -0.293258  -0.098965
# Pressure3pm       1.000000 -0.002107 -0.014624 -0.442529 -0.382657  -0.028149
# Cloud9am         -0.002107  1.000000  0.570442 -0.137649 -0.266713   0.267858
# Cloud3pm         -0.014624  0.570442  1.000000 -0.127397 -0.290356   0.235157
# Temp9am          -0.442529 -0.137649 -0.127397  1.000000  0.834884  -0.094349
# Temp3pm          -0.382657 -0.266713 -0.290356  0.834884  1.000000  -0.229670
# RainToday        -0.028149  0.267858  0.235157 -0.094349 -0.229670   1.000000
# RainTomorrow     -0.124953  0.269598  0.337922 -0.021459 -0.191706   0.294528
# Day              -0.014267 -0.006085 -0.001246  0.011775  0.015433  -0.017186
# Month             0.014114 -0.017524 -0.002678 -0.166721 -0.177947   0.003770
# Year              0.018945  0.008142 -0.000133  0.086060  0.134569  -0.008844
#
#                RainTomorrow       Day     Month      Year
# Location           0.009222 -0.004978 -0.086011  0.481143
# MinTemp            0.091021  0.010924 -0.247066  0.040001
# MaxTemp           -0.149708  0.017068 -0.164351  0.120204
# Rainfall           0.322561 -0.018118 -0.006507  0.007964
# Evaporation       -0.087385  0.010289 -0.048615  0.143626
# Sunshine          -0.287585  0.000222  0.000896  0.106974
# WindGustDir        0.044378  0.017003  0.038044 -0.096042
# WindGustSpeed      0.169135 -0.005673  0.047951 -0.021156
# WindDir9am         0.027091 -0.010014  0.018344 -0.034468
# WindDir3pm         0.003674 -0.000714  0.028629 -0.010781
# WindSpeed9am       0.047118 -0.016257  0.034001 -0.113258
# WindSpeed3pm       0.042472 -0.011662  0.042030 -0.062476
# Humidity9am        0.269722  0.007266 -0.113279  0.107023
# Humidity3pm        0.445891  0.015470 -0.074194 -0.027339
# Pressure9am       -0.152692 -0.017773  0.019322  0.037775
# Pressure3pm       -0.124953 -0.014267  0.014114  0.018945
# Cloud9am           0.269598 -0.006085 -0.017524  0.008142
# Cloud3pm           0.337922 -0.001246 -0.002678 -0.000133
# Temp9am           -0.021459  0.011775 -0.166721  0.086060
# Temp3pm           -0.191706  0.015433 -0.177947  0.134569
# RainToday          0.294528 -0.017186  0.003770 -0.008844
# RainTomorrow       1.000000 -0.012493  0.000135 -0.003180
# Day               -0.012493  1.000000 -0.002263 -0.003481
# Month              0.000135 -0.002263  1.000000 -0.092951
# Year              -0.003180 -0.003481 -0.092951  1.000000
#
# [25 rows x 25 columns]

# %%
plt.figure(figsize=(20,15))    
sns.heatmap(new_df.corr(),linewidths=.1,vmin=-1, vmax=1,fmt='.1g',annot=True,annot_kws={'size':10})
plt.yticks(rotation=45)
plt.show()

# %%
corr['RainTomorrow'].sort_values(ascending=False)
# Out:
# RainTomorrow     1.000000
# Humidity3pm      0.445891
# Cloud3pm         0.337922
# Rainfall         0.322561
# RainToday        0.294528
# Humidity9am      0.269722
# Cloud9am         0.269598
# WindGustSpeed    0.169135
# MinTemp          0.091021
# WindSpeed9am     0.047118
# WindGustDir      0.044378
# WindSpeed3pm     0.042472
# WindDir9am       0.027091
# Location         0.009222
# WindDir3pm       0.003674
# Month            0.000135
# Year            -0.003180
# Day             -0.012493
# Temp9am         -0.021459
# Evaporation     -0.087385
# Pressure3pm     -0.124953
# MaxTemp         -0.149708
# Pressure9am     -0.152692
# Temp3pm         -0.191706
# Sunshine        -0.287585
# Name: RainTomorrow, dtype: float64

# %%
corr['Rainfall'].sort_values(ascending=False)
# Out:
# Rainfall         1.000000
# RainToday        0.903292
# Humidity9am      0.400047
# Humidity3pm      0.380798
# RainTomorrow     0.322561
# Cloud9am         0.295058
# Cloud3pm         0.259063
# WindDir9am       0.155484
# WindGustDir      0.124172
# WindDir3pm       0.113229
# WindGustSpeed    0.080302
# MinTemp          0.073519
# WindSpeed3pm     0.020535
# WindSpeed9am     0.015092
# Location         0.013245
# Year             0.007964
# Month           -0.006507
# Day             -0.018118
# Pressure3pm     -0.031431
# Temp9am         -0.094134
# Pressure9am     -0.108021
# Evaporation     -0.169206
# Sunshine        -0.208747
# MaxTemp         -0.229296
# Temp3pm         -0.239093
# Name: Rainfall, dtype: float64

# %% [markdown]
# `highest (positive and negative) and lowest (postive and negative) correlations are evident from the aforementioned outputs.`

# %%
plt.figure(figsize=(20,10))
new_df.corr()['RainTomorrow'].sort_values(ascending=False).drop(['RainTomorrow']).plot(kind='bar',color='b')
plt.xlabel('Feature',fontsize=15)
plt.ylabel('Target',fontsize=15)
plt.title('Correlation between Target and Feature',fontsize=18)
plt.show()

# %%
plt.figure(figsize=(20,10))
new_df.corr()['Rainfall'].sort_values(ascending=False).drop(['Rainfall']).plot(kind='bar',color='b')
plt.xlabel('Feature',fontsize=15)
plt.ylabel('Target',fontsize=15)
plt.title('Correlation between Target and Feature',fontsize=18)
plt.show()

# %% [markdown]
# ## 1. Predicting whether or not it will RainTomorrow

# %%
x = new_df.drop("RainTomorrow", axis=1)
y = new_df["RainTomorrow"]

# %% [markdown]
# ## Feature Scaling

# %%
scaler = StandardScaler()
x = pd.DataFrame(scaler.fit_transform(x), columns=x.columns)
x
# Out:
#       Location   MinTemp   MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0    -1.508427  0.056444 -0.145732  0.432100     0.255563  0.153323
# 1    -1.508427 -1.058476  0.220676 -0.614634     0.255563  0.153323
# 2    -1.508427 -0.036466  0.320605 -0.614634     0.255563  0.153323
# 3    -1.508427 -0.724000  0.703668 -0.614634     0.255563  0.153323
# 4    -1.508427  0.818306  1.419829  0.626406     0.255563  0.153323
# ...        ...       ...       ...       ...          ...       ...
# 7982  1.029423 -1.913248 -0.062457 -0.614634     0.255563  0.153323
# 7983  1.029423 -1.764592  0.253986 -0.614634     0.255563  0.153323
# 7984  1.029423 -1.430116  0.520464 -0.614634     0.255563  0.153323
# 7985  1.029423 -0.984148  0.537119 -0.614634     0.255563  0.153323
# 7986  1.029423  0.335174  0.014151 -0.614634     0.255563  0.153323
#
#       WindGustDir  WindGustSpeed  WindDir9am  WindDir3pm  ...  Pressure9am  \
# 0        1.229267       0.453782    1.250245    1.400214  ...    -1.687142
# 1        1.441960       0.453782   -0.277857    1.626597  ...    -1.202435
# 2        1.654654       0.594201    1.250245    1.626597  ...    -1.703856
# 3       -0.684977      -1.267099    0.377044   -1.769138  ...    -0.032451
# 4        1.229267       0.234941   -1.369358   -0.184462  ...    -1.169007
# ...           ...            ...         ...         ...  ...          ...
# 7982    -1.535751      -0.582632    0.377044   -1.542755  ...     1.137532
# 7983    -0.259589      -1.486815    0.377044   -1.089991  ...     0.953678
# 7984    -0.897670      -0.074131    0.377044    1.400214  ...     0.535827
# 7985     0.378492      -0.861852    0.595344   -1.089991  ...     0.268402
# 7986    -0.897670       0.172857   -1.151057   -1.316373  ...     0.402114
#
#       Pressure3pm  Cloud9am  Cloud3pm   Temp9am   Temp3pm  RainToday  \
# 0       -1.398115  1.425345  0.013138 -0.138099 -0.098593  -0.542476
# 1       -1.279988  0.011773  0.013138 -0.084254  0.329747  -0.542476
# 2       -1.128109  0.011773 -1.076661  0.597788  0.141277  -0.542476
# 3       -0.436219  0.011773  0.013138  0.077282  0.706687  -0.542476
# 4       -1.583744  1.013630  1.535531  0.023437  1.254963  -0.542476
# ...           ...       ...       ...       ...       ...        ...
# 7982     0.829435  0.011773  0.013138 -1.358595  0.004208  -0.542476
# 7983     0.626930  0.011773  0.013138 -1.215007  0.364014  -0.542476
# 7984     0.238796  0.011773  0.013138 -0.927832  0.638152  -0.542476
# 7985     0.188170 -0.633229 -1.076661 -0.461172  0.621019  -0.542476
# 7986     0.424426  1.425345  1.535531 -0.479120 -0.252796  -0.542476
#
#            Day     Month      Year
# 0    -1.671657  1.634113 -1.661315
# 1    -1.557976  1.634113 -1.661315
# 2    -1.444296  1.634113 -1.661315
# 3    -1.330616  1.634113 -1.661315
# 4    -1.216936  1.634113 -1.661315
# ...        ...       ...       ...
# 7982  0.601949 -0.123726  2.004134
# 7983  0.715629 -0.123726  2.004134
# 7984  0.829310 -0.123726  2.004134
# 7985  0.942990 -0.123726  2.004134
# 7986  1.056670 -0.123726  2.004134
#
# [7987 rows x 24 columns]

# %% [markdown]
# `Bias removed using standard scaler`

# %% [markdown]
# ## Multicollinearity Check (VIF)

# %%
vif = pd.DataFrame()
vif["VIF values"] = [variance_inflation_factor(x.values,i)
    for i in range(len(x.columns))]
vif["Features"] = x.columns

vif
# Out:
#     VIF values       Features
# 0     1.585826       Location
# 1     8.742794        MinTemp
# 2    26.402605        MaxTemp
# 3     5.829876       Rainfall
# 4     1.491861    Evaporation
# 5     1.587987       Sunshine
# 6     1.620367    WindGustDir
# 7     2.191342  WindGustSpeed
# 8     1.407194     WindDir9am
# 9     1.493441     WindDir3pm
# 10    1.791130   WindSpeed9am
# 11    1.978116   WindSpeed3pm
# 12    3.965565    Humidity9am
# 13    5.406903    Humidity3pm
# 14   19.994283    Pressure9am
# 15   19.106493    Pressure3pm
# 16    1.865703       Cloud9am
# 17    1.738761       Cloud3pm
# 18   17.433492        Temp9am
# 19   33.314372        Temp3pm
# 20    5.470232      RainToday
# 21    1.004310            Day
# 22    1.154399          Month
# 23    1.525130           Year

# %% [markdown]
# **High VIF**:
# - MaxTemp
# - Pressure9am
# - Pressure3pm
# - Temp9am
# - Temp3pm

# %%
# dropping column with highest vif
x.drop("Temp3pm",axis=1,inplace=True)

# %%
vif = pd.DataFrame()
vif["VIF values"] = [variance_inflation_factor(x.values,i)
    for i in range(len(x.columns))]
vif["Features"] = x.columns

vif
# Out:
#     VIF values       Features
# 0     1.584698       Location
# 1     8.704020        MinTemp
# 2     9.632907        MaxTemp
# 3     5.828166       Rainfall
# 4     1.490178    Evaporation
# 5     1.586647       Sunshine
# 6     1.617223    WindGustDir
# 7     2.183070  WindGustSpeed
# 8     1.406586     WindDir9am
# 9     1.492318     WindDir3pm
# 10    1.790723   WindSpeed9am
# 11    1.975922   WindSpeed3pm
# 12    3.528640    Humidity9am
# 13    3.660342    Humidity3pm
# 14   19.402071    Pressure9am
# 15   18.608866    Pressure3pm
# 16    1.865014       Cloud9am
# 17    1.727248       Cloud3pm
# 18   16.074247        Temp9am
# 19    5.467667      RainToday
# 20    1.003858            Day
# 21    1.139496          Month
# 22    1.525039           Year

# %%
# dropping column with highest vif
x.drop("Pressure9am",axis=1,inplace=True)

# %%
vif = pd.DataFrame()
vif["VIF values"] = [variance_inflation_factor(x.values,i)
    for i in range(len(x.columns))]
vif["Features"] = x.columns

vif
# Out:
#     VIF values       Features
# 0     1.584622       Location
# 1     8.558294        MinTemp
# 2     9.224295        MaxTemp
# 3     5.814426       Rainfall
# 4     1.478792    Evaporation
# 5     1.586401       Sunshine
# 6     1.602260    WindGustDir
# 7     2.162683  WindGustSpeed
# 8     1.382371     WindDir9am
# 9     1.426259     WindDir3pm
# 10    1.781368   WindSpeed9am
# 11    1.960310   WindSpeed3pm
# 12    3.528632    Humidity9am
# 13    3.658293    Humidity3pm
# 14    1.437350    Pressure3pm
# 15    1.865002       Cloud9am
# 16    1.723989       Cloud3pm
# 17   16.031574        Temp9am
# 18    5.467490      RainToday
# 19    1.003199            Day
# 20    1.138724          Month
# 21    1.522886           Year

# %%
# dropping column with highest vif
x.drop("Temp9am",axis=1,inplace=True)

# %%
vif = pd.DataFrame()
vif["VIF values"] = [variance_inflation_factor(x.values,i)
    for i in range(len(x.columns))]
vif["Features"] = x.columns

vif
# Out:
#     VIF values       Features
# 0     1.582849       Location
# 1     4.529095        MinTemp
# 2     5.354946        MaxTemp
# 3     5.806678       Rainfall
# 4     1.474422    Evaporation
# 5     1.582690       Sunshine
# 6     1.600354    WindGustDir
# 7     2.114963  WindGustSpeed
# 8     1.382178     WindDir9am
# 9     1.425890     WindDir3pm
# 10    1.772592   WindSpeed9am
# 11    1.920800   WindSpeed3pm
# 12    2.512345    Humidity9am
# 13    2.892069    Humidity3pm
# 14    1.434291    Pressure3pm
# 15    1.840617       Cloud9am
# 16    1.718329       Cloud3pm
# 17    5.467095      RainToday
# 18    1.002988            Day
# 19    1.124389          Month
# 20    1.498382           Year

# %% [markdown]
# `Multicollinearity has been removed`

# %% [markdown]
# ## Data Imbalance

# %%
y.value_counts()
# Out:
# 0    6165
# 1    1822
# Name: RainTomorrow, dtype: int64

# %%
SM = SMOTE()
x, y = SM.fit_resample(x,y)

# %%
y.value_counts()
# Out:
# 0    6165
# 1    6165
# Name: RainTomorrow, dtype: int64

# %% [markdown]
# `Dataset has been balanced`

# %% [markdown]
# ## Model Building

# %%
maxAccu=0
maxRS=0
for i in range(1,100):
    x_train,x_test,y_train,y_test = TTS(x,y,test_size=.20, random_state =i)
    rf = RandomForestClassifier()
    rf.fit(x_train, y_train)
    pred = rf.predict(x_test)
    acc=accuracy_score(y_test, pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print("Best accuracy is ",maxAccu," on Random_state ",maxRS)
# Out:
# Best accuracy is  0.948499594484996  on Random_state  93

# %%
x_train,x_test,y_train,y_test=TTS(x,y,test_size=.20,random_state=maxRS)

# %%
dt = DecisionTreeClassifier()
rf = RandomForestClassifier()
lr= LogisticRegression()
svc =  SVC()
knn = KNeighborsClassifier()

# %%
dt.fit(x_train,y_train)
rf.fit(x_train,y_train)
svc.fit(x_train,y_train)
lr.fit(x_train,y_train)
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %% [markdown]
# #### Decision Tree

# %%
dt_pred = dt.predict(x_test)
accu = classification_report(y_test,dt_pred)

# %%
cm = confusion_matrix(y_test,dt_pred)

# %%
cm
# Out:
# array([[1113,  136],
#        [ 123, 1094]])

# %%
print(accu)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.89      0.90      1249
#            1       0.89      0.90      0.89      1217
#
#     accuracy                           0.89      2466
#    macro avg       0.89      0.90      0.89      2466
# weighted avg       0.90      0.89      0.89      2466

# %% [markdown]
# #### Logisitic Regression

# %%
lr_pred = lr.predict(x_test)
accu = classification_report(y_test,lr_pred)

# %%
cm = confusion_matrix(y_test,lr_pred)

# %%
cm
# Out:
# array([[977, 272],
#        [295, 922]])

# %%
print(accu)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.78      0.78      1249
#            1       0.77      0.76      0.76      1217
#
#     accuracy                           0.77      2466
#    macro avg       0.77      0.77      0.77      2466
# weighted avg       0.77      0.77      0.77      2466

# %% [markdown]
# #### Random Forest

# %%
rf_pred = rf.predict(x_test)
accu = classification_report(y_test,rf_pred)

# %%
cm = confusion_matrix(y_test,rf_pred)

# %%
cm
# Out:
# array([[1180,   69],
#        [  63, 1154]])

# %%
print(accu)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.94      0.95      1249
#            1       0.94      0.95      0.95      1217
#
#     accuracy                           0.95      2466
#    macro avg       0.95      0.95      0.95      2466
# weighted avg       0.95      0.95      0.95      2466

# %% [markdown]
# #### SVC

# %%
svc_pred = svc.predict(x_test)
accu = classification_report(y_test,svc_pred)

# %%
cm = confusion_matrix(y_test,svc_pred)

# %%
cm
# Out:
# array([[1055,  194],
#        [ 132, 1085]])

# %%
print(accu)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.84      0.87      1249
#            1       0.85      0.89      0.87      1217
#
#     accuracy                           0.87      2466
#    macro avg       0.87      0.87      0.87      2466
# weighted avg       0.87      0.87      0.87      2466

# %% [markdown]
# #### K Nearest Neighbor

# %%
knn_pred = knn.predict(x_test)
accu = classification_report(y_test,knn_pred)

# %%
cm = confusion_matrix(y_test,knn_pred)

# %%
cm
# Out:
# array([[ 957,  292],
#        [  32, 1185]])

# %%
print(accu)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.77      0.86      1249
#            1       0.80      0.97      0.88      1217
#
#     accuracy                           0.87      2466
#    macro avg       0.88      0.87      0.87      2466
# weighted avg       0.89      0.87      0.87      2466

# %% [markdown]
# #### Model Cross Validation

# %%
print("Cross Validation Score for Decision Tree: ",cross_val_score(dt,x,y,cv=5).mean())
print("Cross Validation Score for Logistic Regression: ",cross_val_score(lr,x,y,cv=5).mean())
print("Cross Validation Score for Random Forest: ",cross_val_score(rf,x,y,cv=5).mean())
print("Cross Validation Score for SVC: ",cross_val_score(svc,x,y,cv=5).mean())
print("Cross Validation Score for KNN: ",cross_val_score(knn,x,y,cv=5).mean())
# Out:
# Cross Validation Score for Decision Tree:  0.73227899432279
# Cross Validation Score for Logistic Regression:  0.7158150851581508
# Cross Validation Score for Random Forest:  0.7978102189781022
# Cross Validation Score for SVC:  0.740470397404704
# Cross Validation Score for KNN:  0.7356853203568533

# %% [markdown]
# #### `Random Forest` appears to be the best model

# %% [markdown]
# #### ROC AUC Scores

# %%
print("ROC AUC Score for Decision Tree: ", roc_auc_score(y_test,dt_pred),"\n")
print("ROC AUC Score for Logistic Regression: ", roc_auc_score(y_test,lr_pred),"\n")
print("ROC AUC Score for Random Forest: ", roc_auc_score(y_test,rf_pred),"\n")
print("ROC AUC Score for SVC: ", roc_auc_score(y_test,svc_pred),"\n")
print("ROC AUC Score for KNN: ", roc_auc_score(y_test,knn_pred))
# Out:
# ROC AUC Score for Decision Tree:  0.8950223449096172
#
# ROC AUC Score for Logistic Regression:  0.7699132189893246
#
# ROC AUC Score for Random Forest:  0.9464945826834024
#
# ROC AUC Score for SVC:  0.8681061529585212
#
# ROC AUC Score for KNN:  0.869959402197189

# %%
disp = plot_roc_curve(dt,x_test,y_test)
mod = [lr,rf,svc,knn]
for i in mod:
    plot_roc_curve(i,x_test,y_test, ax=disp.ax_)
plt.legend(prop={'size':10}, loc = 'lower right')
plt.show()

# %% [markdown]
# #### `Random Forest` is the best model

# %% [markdown]
# ## Hyperparameter Tuning

# %%
parameter = {'n_estimators':[30,50],
             'max_depth': [10,20,30],
             'min_samples_leaf':[3,5,10],
             'min_samples_split':[2,5,10],
             'criterion':['gini','entropy'],
             'max_features':["auto","sqrt"]
            }

# %%
GridCV = GridSearchCV(RandomForestClassifier(),parameter,cv=5,n_jobs = -1)

# %%
GridCV.fit(x_train,y_train)
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
# ...
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# GridSearchCV(cv=5, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [10, 20, 30],
#                          'max_features': ['auto', 'sqrt'],
#                          'min_samples_leaf': [3, 5, 10],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [30, 50]})

# %%
GridCV.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 20,
#  'max_features': 'auto',
#  'min_samples_leaf': 3,
#  'min_samples_split': 2,
#  'n_estimators': 50}

# %%
Best_mod = RandomForestClassifier(n_estimators = 50,
                                   criterion = 'entropy', 
                                   max_depth= 30, 
                                   max_features = 'auto', 
                                   min_samples_leaf = 3, 
                                   min_samples_split = 5)
Best_mod.fit(x_train,y_train)
rfpred = Best_mod.predict(x_test)
acc = accuracy_score(y_test,rfpred)
print(acc*100)
# Out:
# 93.34955393349554

# %%
cm = confusion_matrix(y_test,rfpred)

x_axis_labels = ["0","1"]
y_axis_labels = ["0","1"]

f , ax = plt.subplots(figsize=(7,7))
sns.heatmap(cm, annot = True,linewidths=.2, fmt = ".0f", ax=ax,xticklabels=x_axis_labels,yticklabels=y_axis_labels)

plt.xlabel("PREDICTED LABEL")
plt.ylabel("TRUE LABEL")
plt.title('Confusion Matrix for  Final Model')
plt.show()

# %%
plot_roc_curve(Best_mod, x_test, y_test)
plt.title("ROC for the best model")
plt.show()

# %% [markdown]
# ## Saving the model and reloading to predict

# %%
joblib.dump(Best_mod,"Rainfall_Prediction_Weather_Forecasting.pkl")
# Out:
# ['Rainfall_Prediction_Weather_Forecasting.pkl']

# %%
model = joblib.load("Rainfall_Prediction_Weather_Forecasting.pkl")

prediction = model.predict(x_test)
prediction
# Out:
# array([0, 1, 0, ..., 0, 0, 1])

# %%
orgi = np.array(y_test)
df = pd.DataFrame()
df["Predicted"] = prediction
df["Original"] = a
df
# Out:
#       Predicted  Original
# 0             0         1
# 1             1         1
# 2             0         1
# 3             0         1
# 4             1         0
# ...         ...       ...
# 2461          0         1
# 2462          1         0
# 2463          0         0
# 2464          0         1
# 2465          1         0
#
# [2466 rows x 2 columns]

# %% [markdown]
# ## 2. Predicting how much rainfall could be there

# %%
new_df.head()
# Out:
#    Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustDir  \
# 0         1     13.4     22.9  0.843433     1.753261  1.968868           13
# 1         1      7.4     25.1  0.000000     1.753261  1.968868           14
# 2         1     12.9     25.7  0.000000     1.753261  1.968868           15
# 3         1      9.2     28.0  0.000000     1.753261  1.968868            4
# 4         1     17.5     32.3  1.000000     1.753261  1.968868           13
#
#    WindGustSpeed  WindDir9am  WindDir3pm  ...  Pressure3pm  Cloud9am  \
# 0       3.530348          13          14  ...       1007.1  8.000000
# 1       3.530348           6          15  ...       1007.8  4.566622
# 2       3.583048          13          15  ...       1008.7  4.566622
# 3       2.884499           9           0  ...       1012.8  4.566622
# 4       3.448217           1           7  ...       1006.0  7.000000
#
#    Cloud3pm  Temp9am  Temp3pm  RainToday  RainTomorrow  Day  Month  Year
# 0  4.503183     16.9     21.8          0             0    1     12  2008
# 1  4.503183     17.2     24.3          0             0    2     12  2008
# 2  2.000000     21.0     23.2          0             0    3     12  2008
# 3  4.503183     18.1     26.5          0             0    4     12  2008
# 4  8.000000     17.8     29.7          0             0    5     12  2008
#
# [5 rows x 25 columns]

# %%
x = new_df.drop("Rainfall", axis=1)
y = new_df["Rainfall"]

# %%
scaler = StandardScaler()
x = pd.DataFrame(scaler.fit_transform(x), columns=x.columns)
x
# Out:
#       Location   MinTemp   MaxTemp  Evaporation  Sunshine  WindGustDir  \
# 0    -1.508427  0.056444 -0.145732     0.255563  0.153323     1.229267
# 1    -1.508427 -1.058476  0.220676     0.255563  0.153323     1.441960
# 2    -1.508427 -0.036466  0.320605     0.255563  0.153323     1.654654
# 3    -1.508427 -0.724000  0.703668     0.255563  0.153323    -0.684977
# 4    -1.508427  0.818306  1.419829     0.255563  0.153323     1.229267
# ...        ...       ...       ...          ...       ...          ...
# 7982  1.029423 -1.913248 -0.062457     0.255563  0.153323    -1.535751
# 7983  1.029423 -1.764592  0.253986     0.255563  0.153323    -0.259589
# 7984  1.029423 -1.430116  0.520464     0.255563  0.153323    -0.897670
# 7985  1.029423 -0.984148  0.537119     0.255563  0.153323     0.378492
# 7986  1.029423  0.335174  0.014151     0.255563  0.153323    -0.897670
#
#       WindGustSpeed  WindDir9am  WindDir3pm  WindSpeed9am  ...  Pressure3pm  \
# 0          0.453782    1.250245    1.400214      0.707154  ...    -1.398115
# 1          0.453782   -0.277857    1.626597     -0.647365  ...    -1.279988
# 2          0.594201    1.250245    1.626597      0.651849  ...    -1.128109
# 3         -1.267099    0.377044   -1.769138      0.117716  ...    -0.436219
# 4          0.234941   -1.369358   -0.184462     -0.256122  ...    -1.583744
# ...             ...         ...         ...           ...  ...          ...
# 7982      -0.582632    0.377044   -1.542755      0.270778  ...     0.829435
# 7983      -1.486815    0.377044   -1.089991      0.270778  ...     0.626930
# 7984      -0.074131    0.377044    1.400214     -0.055228  ...     0.238796
# 7985      -0.861852    0.595344   -1.089991      0.270778  ...     0.188170
# 7986       0.172857   -1.151057   -1.316373      0.535124  ...     0.424426
#
#       Cloud9am  Cloud3pm   Temp9am   Temp3pm  RainToday  RainTomorrow  \
# 0     1.425345  0.013138 -0.138099 -0.098593  -0.542476     -0.543635
# 1     0.011773  0.013138 -0.084254  0.329747  -0.542476     -0.543635
# 2     0.011773 -1.076661  0.597788  0.141277  -0.542476     -0.543635
# 3     0.011773  0.013138  0.077282  0.706687  -0.542476     -0.543635
# 4     1.013630  1.535531  0.023437  1.254963  -0.542476     -0.543635
# ...        ...       ...       ...       ...        ...           ...
# 7982  0.011773  0.013138 -1.358595  0.004208  -0.542476     -0.543635
# 7983  0.011773  0.013138 -1.215007  0.364014  -0.542476     -0.543635
# 7984  0.011773  0.013138 -0.927832  0.638152  -0.542476     -0.543635
# 7985 -0.633229 -1.076661 -0.461172  0.621019  -0.542476     -0.543635
# 7986  1.425345  1.535531 -0.479120 -0.252796  -0.542476     -0.543635
#
#            Day     Month      Year
# 0    -1.671657  1.634113 -1.661315
# 1    -1.557976  1.634113 -1.661315
# 2    -1.444296  1.634113 -1.661315
# 3    -1.330616  1.634113 -1.661315
# 4    -1.216936  1.634113 -1.661315
# ...        ...       ...       ...
# 7982  0.601949 -0.123726  2.004134
# 7983  0.715629 -0.123726  2.004134
# 7984  0.829310 -0.123726  2.004134
# 7985  0.942990 -0.123726  2.004134
# 7986  1.056670 -0.123726  2.004134
#
# [7987 rows x 24 columns]

# %%
vif = pd.DataFrame()
vif["VIF values"] = [variance_inflation_factor(x.values,i)
    for i in range(len(x.columns))]
vif["Features"] = x.columns

vif
# Out:
#     VIF values       Features
# 0     1.596634       Location
# 1     8.753144        MinTemp
# 2    26.373771        MaxTemp
# 3     1.491817    Evaporation
# 4     1.599909       Sunshine
# 5     1.622692    WindGustDir
# 6     2.257110  WindGustSpeed
# 7     1.405987     WindDir9am
# 8     1.493746     WindDir3pm
# 9     1.793315   WindSpeed9am
# 10    1.982280   WindSpeed3pm
# 11    3.916219    Humidity9am
# 12    5.649444    Humidity3pm
# 13   19.983253    Pressure9am
# 14   19.154031    Pressure3pm
# 15    1.865499       Cloud9am
# 16    1.754263       Cloud3pm
# 17   17.421596        Temp9am
# 18   33.304608        Temp3pm
# 19    1.363622      RainToday
# 20    1.437457   RainTomorrow
# 21    1.004639            Day
# 22    1.154357          Month
# 23    1.529142           Year

# %%
# dropping column with highest vif
x.drop("Temp3pm",axis=1,inplace=True)

# %%
vif = pd.DataFrame()
vif["VIF values"] = [variance_inflation_factor(x.values,i)
    for i in range(len(x.columns))]
vif["Features"] = x.columns

vif
# Out:
#     VIF values       Features
# 0     1.595523       Location
# 1     8.713998        MinTemp
# 2     9.630578        MaxTemp
# 3     1.490158    Evaporation
# 4     1.598570       Sunshine
# 5     1.619525    WindGustDir
# 6     2.249103  WindGustSpeed
# 7     1.405411     WindDir9am
# 8     1.492669     WindDir3pm
# 9     1.792901   WindSpeed9am
# 10    1.980043   WindSpeed3pm
# 11    3.474121    Humidity9am
# 12    3.902463    Humidity3pm
# 13   19.396989    Pressure9am
# 14   18.661268    Pressure3pm
# 15    1.864795       Cloud9am
# 16    1.742828       Cloud3pm
# 17   16.057271        Temp9am
# 18    1.363369      RainToday
# 19    1.437456   RainTomorrow
# 20    1.004194            Day
# 21    1.139507          Month
# 22    1.529041           Year

# %%
# dropping column with highest vif
x.drop("Pressure9am",axis=1,inplace=True)

# %%
vif = pd.DataFrame()
vif["VIF values"] = [variance_inflation_factor(x.values,i)
    for i in range(len(x.columns))]
vif["Features"] = x.columns

vif
# Out:
#     VIF values       Features
# 0     1.595513       Location
# 1     8.570207        MinTemp
# 2     9.220860        MaxTemp
# 3     1.478784    Evaporation
# 4     1.598138       Sunshine
# 5     1.604135    WindGustDir
# 6     2.223570  WindGustSpeed
# 7     1.380847     WindDir9am
# 8     1.426636     WindDir3pm
# 9     1.783871   WindSpeed9am
# 10    1.965561   WindSpeed3pm
# 11    3.474044    Humidity9am
# 12    3.901931    Humidity3pm
# 13    1.448383    Pressure3pm
# 14    1.864790       Cloud9am
# 15    1.738722       Cloud3pm
# 16   16.012570        Temp9am
# 17    1.349151      RainToday
# 18    1.434443   RainTomorrow
# 19    1.003607            Day
# 20    1.138799          Month
# 21    1.527310           Year

# %%
# dropping column with highest vif
x.drop("Temp9am",axis=1,inplace=True)

# %%
vif = pd.DataFrame()
vif["VIF values"] = [variance_inflation_factor(x.values,i)
    for i in range(len(x.columns))]
vif["Features"] = x.columns

vif
# Out:
#     VIF values       Features
# 0     1.593892       Location
# 1     4.532033        MinTemp
# 2     5.364756        MaxTemp
# 3     1.474373    Evaporation
# 4     1.594596       Sunshine
# 5     1.602198    WindGustDir
# 6     2.178745  WindGustSpeed
# 7     1.380614     WindDir9am
# 8     1.426312     WindDir3pm
# 9     1.775105   WindSpeed9am
# 10    1.926699   WindSpeed3pm
# 11    2.473815    Humidity9am
# 12    3.124829    Humidity3pm
# 13    1.445118    Pressure3pm
# 14    1.840619       Cloud9am
# 15    1.733424       Cloud3pm
# 16    1.345980      RainToday
# 17    1.434232   RainTomorrow
# 18    1.003379            Day
# 19    1.124311          Month
# 20    1.502155           Year

# %% [markdown]
# ## Model Building

# %%
maxAccu=0
maxRS=0
for i in range(1,100):
    x_train,x_test,y_train,y_test = TTS(x,y,test_size=.20, random_state=i)
    mod = RandomForestRegressor()
    mod.fit(x_train, y_train)
    pred = mod.predict(x_test)
    acc=r2_score(y_test, pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print("Maximum r2 score is ",maxAccu," on Random_state ",maxRS)
# Out:
# Maximum r2 score is  0.889009276167852  on Random_state  1

# %%
x_train,x_test,y_train,y_test = TTS(x,y,test_size=0.20,random_state=maxRS)

# %%
lr = LinearRegression()
rf = RandomForestRegressor()
svr = SVR()
dt = DecisionTreeRegressor()

# %%
lr.fit(x_train,y_train)
rf.fit(x_train,y_train)
svr.fit(x_train,y_train)
dt.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
print("-"*50)
print("Linear Regression Model")
print("-"*50)
lr_pred = lr.predict(x_test)
print("R2 Score: ", r2_score(y_test,lr_pred), "\n")
print("Mean Squared Error: ", mean_squared_error(y_test,lr_pred), "\n"*2)

print("-"*50)
print("Random Forest Model")
print("-"*50)
rf_pred = rf.predict(x_test)
print("R2 Score: ", r2_score(y_test,rf_pred), "\n")
print("Mean Squared Error: ", mean_squared_error(y_test,rf_pred), "\n"*2)

print("-"*50)
print("Support Vector Regression Model")
print("-"*50)
svr_pred = svr.predict(x_test)
print("R2 Score: ", r2_score(y_test,svr_pred), "\n")
print("Mean Squared Error: ", mean_squared_error(y_test,svr_pred), "\n"*2)

print("-"*50)
print("Decision Tree Model")
print("-"*50)
dt_pred = dt.predict(x_test)
print("R2 Score: ", r2_score(y_test,dt_pred), "\n")
print("Mean Squared Error: ", mean_squared_error(y_test,dt_pred), "\n"*2)
# Out:
# --------------------------------------------------
# Linear Regression Model
# --------------------------------------------------
# R2 Score:  0.8396957943178731
#
# Mean Squared Error:  0.11003165951919565
#
#
# --------------------------------------------------
# Random Forest Model
# --------------------------------------------------
# R2 Score:  0.8884567887259222
#
# Mean Squared Error:  0.07656246192894146
#
#
# --------------------------------------------------
# Support Vector Regression Model
# --------------------------------------------------
# R2 Score:  0.8494471703629474
#
# Mean Squared Error:  0.10333838479025398
#
#
# --------------------------------------------------
# Decision Tree Model
# --------------------------------------------------
# R2 Score:  0.7970283303663888
#
# Mean Squared Error:  0.13931830141408583

# %% [markdown]
# #### Model Cross Validation

# %%
print("Cross Validation Score for Linear Regression Model: ", cross_val_score(lr,x,y,cv=5).mean(), "\n"*2)
print("Cross Validation Score for Random Forest Model: ", cross_val_score(rf,x,y,cv=5).mean(), "\n"*2)
print("Cross Validation Score for Support Vector Regression Model: ", cross_val_score(svr,x,y,cv=5).mean(), "\n"*2)
print("Cross Validation Score for Decision Tree Model: ", cross_val_score(dt,x,y,cv=5).mean(), "\n"*2)
# Out:
# Cross Validation Score for Linear Regression Model:  0.8255025047161727
#
#
# Cross Validation Score for Random Forest Model:  0.8548323965925311
#
#
# Cross Validation Score for Support Vector Regression Model:  0.820746121507355
#
#
# Cross Validation Score for Decision Tree Model:  0.7306861264556479

# %% [markdown]
# #### `Random Forest` appears to be the best model

# %% [markdown]
# ## Hyperparameter Tuning

# %%
parameters = {'n_estimators':[10,50,100],
              'max_depth':[10,20,30],
              'max_features':['auto','sqrt'],
              'min_samples_leaf': [2, 3, 5],
              'min_samples_split': [2, 3, 5, 10]
             }

# %%
GCV = GridSearchCV(RandomForestRegressor(),parameters,cv=5)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [10, 20, 30],
#                          'max_features': ['auto', 'sqrt'],
#                          'min_samples_leaf': [2, 3, 5],
#                          'min_samples_split': [2, 3, 5, 10],
#                          'n_estimators': [10, 50, 100]})

# %%
GCV.best_params_
# Out:
# {'max_depth': 30,
#  'max_features': 'auto',
#  'min_samples_leaf': 2,
#  'min_samples_split': 3,
#  'n_estimators': 100}

# %%
Final_model = RandomForestRegressor(max_depth=20, max_features='auto', min_samples_leaf=2, min_samples_split=2, n_estimators=100)
Final_model.fit(x_train,y_train)
pred = Final_model.predict(x_test)
print('R2_Score:',r2_score(y_test,pred)*100)
print("RMSE value:",np.sqrt(metrics.mean_squared_error(y_test, pred)))
print('MAE:',metrics.mean_absolute_error(y_test, pred))
print('MSE:',metrics.mean_squared_error(y_test, pred))
# Out:
# R2_Score: 88.62613816308348
# RMSE value: 0.279408972023048
# MAE: 0.17814651562385012
# MSE: 0.0780693736469764

# %% [markdown]
# `Post hyperparameter tuning, the r2 score is 88.35%`

# %% [markdown]
# ## Saving the model and reloading for prediction

# %%
joblib.dump(Final_model,'Rainfall_Prediction_Weather_Forecasting_(Rainfall).pkl')
# Out:
# ['Rainfall_Prediction_Weather_Forecasting_(Rainfall).pkl']

# %%
Model = joblib.load("Rainfall_Prediction_Weather_Forecasting_(Rainfall).pkl")

orgi= np.array(y_test)
predicted = np.array(Model.predict(x_test))
df_RainfallPred = pd.DataFrame({"Original":orgi,"Predicted":predicted},index= range(len(orgi)))
df_RainfallPred
# Out:
#       Original  Predicted
# 0     1.409460   1.677773
# 1     1.062659   1.696235
# 2     1.686865   1.675265
# 3     0.000000   0.102314
# 4     1.560491   1.677337
# ...        ...        ...
# 1593  1.000000   0.086946
# 1594  0.000000   0.313081
# 1595  0.000000   0.017117
# 1596  0.000000   0.038680
# 1597  0.584804   0.129797
#
# [1598 rows x 2 columns]

# %%
df_RainfallPred.head(50)
# Out:
#     Original  Predicted
# 0   1.409460   1.677773
# 1   1.062659   1.696235
# 2   1.686865   1.675265
# 3   0.000000   0.102314
# 4   1.560491   1.677337
# 5   2.223980   2.329046
# 6   0.000000   0.171050
# 7   2.095379   2.145412
# 8   0.000000   0.017420
# 9   0.000000   0.013054
# 10  0.000000   0.050976
# 11  1.732478   1.803004
# 12  0.000000   0.028813
# 13  0.000000   0.176074
# 14  1.686865   1.723627
# 15  0.000000   0.086884
# 16  0.000000   0.018367
# 17  0.000000   0.003899
# 18  1.338866   1.974296
# 19  0.000000   0.073931
# 20  1.837091   1.761785
# 21  0.000000   0.027082
# 22  0.000000   0.003684
# 23  0.000000   0.002456
# 24  0.000000   0.000000
# 25  0.000000   0.015135
# 26  0.000000   0.055385
# 27  0.000000   0.010881
# 28  2.519842   2.137061
# 29  0.000000   0.061686
# 30  0.000000   0.030421
# 31  0.000000   0.054478
# 32  3.043802   2.756512
# 33  1.532619   1.544559
# 34  2.540668   1.953276
# 35  1.532619   1.776793
# 36  0.000000   0.052789
# 37  0.000000   0.050625
# 38  0.000000   0.132906
# 39  0.000000   0.106131
# 40  0.000000   0.015963
# 41  1.375069   1.922982
# 42  1.930979   1.968147
# 43  0.928318   0.562961
# 44  0.000000   0.293325
# 45  0.000000   0.006839
# 46  1.169607   1.372272
# 47  1.216440   1.613724
# 48  1.062659   1.932433
# 49  1.663103   1.629755

# %% [markdown]
# Concluded
